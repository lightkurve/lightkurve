# %% [markdown]
# # Some injection & recovery with M/L dwarfs

# %% [markdown]
# I'll move this from lightkurve later

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from lightkurve import KeplerTargetPixelFile
import numpy as np
import matplotlib.pyplot as plt
from lightkurve.injection import TransitModel
import lightkurve.injection as inj
import scipy.optimize as op
import batman
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tpf = KeplerTargetPixelFile.from_archive(201453319)
lc = tpf_star.to_lightcurve(aperture_mask='all')

# %%
tpf.plot()

# %%
lc.plot()
