# %%
# %matplotlib inline
# %config IPython.matplotlib.backend = "retina"
from matplotlib import rcParams
rcParams["savefig.dpi"] = 150
rcParams["figure.dpi"] = 150
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter

from astropy.stats import LombScargle

from lightkurve import KeplerLightCurveFile
target = "KIC11615890"
lc = KeplerLightCurveFile.from_archive(target, quarter=0).PDCSAP_FLUX.normalize()
for q in range(1, 17):
    lc = lc.append(KeplerLightCurveFile.from_archive(target, quarter=q).PDCSAP_FLUX.normalize())

lc.plot(seismology=True)
# Out:
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2009131105131_llc.fits with expected size 77760. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2009166043257_llc.fits with expected size 192960. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2009259160929_llc.fits with expected size 466560. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2009350155506_llc.fits with expected size 466560. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2010078095331_llc.fits with expected size 469440. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2010174085026_llc.fits with expected size 492480. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2010265121752_llc.fits with expected size 469440. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2010355172524_llc.fits with expected size 466560. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2011073133259_llc.fits with expected size 357120. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2011177032512_llc.fits with expected size 506880. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2011271113734_llc.fits with expected size 486720. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2012004120508_llc.fits with expected size 506880. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2012088054726_llc.fits with expected size 434880. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2012179063303_llc.fits with expected size 472320. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2012277125453_llc.fits with expected size 506880. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2013011073258_llc.fits with expected size 506880. [astroquery.query]
# INFO: Found cached file ./mastDownload/Kepler/kplr011615890_lc_Q111111111111111111/kplr011615890-2013098041711_llc.fits with expected size 449280. [astroquery.query]

# %%
# %load_ext autoreload
# %autoreload 2

# %%
lc.quality == 0

# %%
np.isfinite(lc.time)
np.isfinite(lc.flux)

# %%
lc.flux[lc.quality==0] - 1
